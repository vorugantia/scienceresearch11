# %% [markdown]
# ## This is a test notebook.

# %% [markdown]
# ### Imports:
#
# (And also a function call to hide warnings)

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='astropy')

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import gammapy

# %%
print(gammapy.version.version)
# Out:
# 0.4

# %% [markdown]
# ### Demo light curve plot:

# %%
from gammapy.catalog import SourceCatalog3FGL #, SourceCatalog2FHL

catalog_3fgl = SourceCatalog3FGL()
source = catalog_3fgl['3FGL J0004.7-4740']

# %%
source.plot_lightcurve()
# plt.savefig('3FGL_J0004.7-4740_lc.png')

# %% [markdown]
# ### Demo fits image:

# %%
from astropy.io import fits

# %%
hdulist = fits.open('C:/Users/arjun_000/github/gammapy-extra/datasets/fermi_survey/all.fits.gz')

# %%
hdulist.info()
# Out:
# Filename: C:/Users/arjun_000/github/gammapy-extra/datasets/fermi_survey/all.fits.gz
# No.    Name         Type      Cards   Dimensions   Format
# 0    COUNTS      PrimaryHDU      84   (2001, 101)   int32
# 1    BACKGROUND  ImageHDU        85   (2001, 101)   float64
# 2    EXPOSURE    ImageHDU        85   (2001, 101)   float32

# %%
hdu1 = hdulist['BACKGROUND']
hdu2 = hdulist['EXPOSURE']

# %%
plt.imshow(hdu1.data, cmap='inferno')
# plt.savefig('fits_image_demo.png', dpi=300)

# %%
plt.imshow(hdu2.data, cmap='viridis')
